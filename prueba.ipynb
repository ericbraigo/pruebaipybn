# %% [markdown]
# Marvinno.<br>
# 06-marzo-2021<br>
# Estudio de programaciÃ³n en Python<br>
# imer cÃ³digo para interactuar con la plataforma de Marvinno

# %%
print("Hola. Bienvenido a Marvinno")
print("Hagamos la primera prueba para la interacciÃ³n con la plataforma")
print("Calculemos el Ã¡rea de un triÃ¡ngulo")

# %%
Bt=5
Ht=7
At=Bt*Ht/2

# %%
print("El Ã¡rea del triÃ¡ngulo es:")
print(At)
a=0
for i in range(5):
    a+=1
    print(a)

# %%
print("Ahora calculemos el Ã¡rea de un cuadrado. Dame la Base Dame la altura")

# %%
Bc=6
Hc=2
Ac=Bc*Hc
print("El Ã¡rea del cuadrado es:")
print(Ac)

# %%
print("Calculemos ahora el perimetro de un cuadrado usando una funciÃ³n")

# %%
def perimetro_cuad(Bc,Hc):
    per=Bc*2+Hc*2
    print(per)

# %%
perimetro_cuad(Bc,Hc)
